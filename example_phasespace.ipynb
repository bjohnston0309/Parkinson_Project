# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math


x = [2,4]
y = [2,5]

plt.plot(x,y,'o', markersize=10)
plt.xlim(0,7)
plt.ylim(0,7)
plt.axhline(2,0,2/7, linestyle='--')
plt.axhline(5,0,4/7, linestyle='--')
plt.axvline(2,0,2/7, linestyle='--')
plt.axvline(4,0,5/7, linestyle='--')
plt.xlabel('$x \longrightarrow$', fontsize=14)
plt.ylabel('$x + \\tau \longrightarrow$', fontsize=14)
plt.xticks([])
plt.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)
