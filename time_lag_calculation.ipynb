# %%
pip install sklearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyinform
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install teaspoon
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
import PyQt5
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

#Importing data from csv file and setting variables
data=np.genfromtxt("../Example Data/real_eyemovement_001_1kHz.csv", delimiter=',')
data1=data.transpose()
t=(data1[0])
x=(data1[1])
y=(data1[2])
# Out:
# [0.00000000e+00 1.00003237e-03 2.00006474e-03 ... 1.92806240e+00
#  1.92906244e+00 1.93006247e+00]

# %%
from teaspoon.parameter_selection.MI_delay import MI_for_delay
import numpy as np

ts1 = x

tau1 = MI_for_delay(ts1, plotting = True, method = 'basic', h_method = 'sturge', k = 2, ranking = True)
print('Delay from MI: ',tau1)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/teaspoon/parameter_selection/MI_delay.py:503: RuntimeWarning: divide by zero encountered in log
#   I_matrix = Pxy*np.log(Pxy/(Px*Py))
# /opt/anaconda3/lib/python3.7/site-packages/teaspoon/parameter_selection/MI_delay.py:503: RuntimeWarning: invalid value encountered in multiply
#   I_matrix = Pxy*np.log(Pxy/(Px*Py))
# Delay from MI:  10

# %%
ts2 = y

tau2 = MI_for_delay(ts2, plotting = True, method = 'basic', h_method = 'sturge', k = 2, ranking = True)
print('Delay from MI: ',tau2)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/teaspoon/parameter_selection/MI_delay.py:503: RuntimeWarning: divide by zero encountered in log
#   I_matrix = Pxy*np.log(Pxy/(Px*Py))
# /opt/anaconda3/lib/python3.7/site-packages/teaspoon/parameter_selection/MI_delay.py:503: RuntimeWarning: invalid value encountered in multiply
#   I_matrix = Pxy*np.log(Pxy/(Px*Py))
# Delay from MI:  30
