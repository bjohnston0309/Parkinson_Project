# %%
#N = len(embedded_x_final)
#eps = 0.001
#lyapunovs = [[] for i in range(N)]

#for i in range(N):
#    for j in range(i + 1, N):
#        if np.sqrt((embedded_x_final[0,i+j]-embedded_x_final[0,i])**2 + (embedded_x_final[1,i+j]-embedded_x_final[1,i])**2 + (embedded_x_final[2,i+j]-embedded_x_final[2,i])**2):
#            for k in range(min(N - i, N - j)):
#                lyapunovs[k].append(np.log(np.abs(embedded_x_final[i+k] - embedded_x_final[j+k])))



######################

 
#div = []

#for i in range(len(lyapunovs)):
#    if len(lyapunovs[i]):
#        div.append(sum(lyapunovs[i]) / len(lyapunovs[i]))
#
#div1=pd.DataFrame(div)
#div2=div1.transpose()
#
#plt.plot(t[0:1765], div2[0:1765])


# Extracting the period of data from the nearest neighbours calculation

#for i in range(len(embedded_x_final.transpose())):

    ##m_x = 0

    #while times_x[i][m_x] < eps:

        #m_x += 1

    #lags_x.append(times_x[i][m_x])
