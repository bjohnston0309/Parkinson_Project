# %%
### Importing the necessary Python libraries and data needed for the calculations of the embedding dimension

# Importing relevant libraries
from teaspoon.parameter_selection.FNN_n import FNN_n
import numpy as np
import pandas as pd
import warnings

# Data import
data=np.genfromtxt("../Example Data/real_eyemovement_001_1kHz.csv", delimiter=',')
df=pd.DataFrame(data)
data_interpolate=df.interpolate(limit_direction='both')
data1=pd.DataFrame.to_numpy(data_interpolate)
data2=data1.transpose()

t=(data2[0])
x=(data2[2])
y=(data2[1])
r = np.sqrt(x**2+y**2)            # Radial component of x and y data

# Ignoring warnings printed to screen
warnings.filterwarnings("ignore")

# %%
### Definition for calculation of the embedding dimesnion

def EMBED_DIM(t,tau):
 
    perc_FNN. n =
# Out:
#   File "<ipython-input-2-96ee2ae1878c>", line 5
#     perc_FNN. n =
#                   ^
# SyntaxError: invalid syntax

# %%
tau = 48
ts = r

perc_FNN, n = FNN_n(ts, tau, plotting = True)
print('FNN embedding Dimension: ',n)
# Out:
# FNN embedding Dimension:  3

# %%
tau1= 48 
ts1= y 

perc_FNN, n = FNN_n(ts1, tau1, plotting = True)
print('FNN embedding Dimension: ',n)
# Out:
# FNN embedding Dimension:  3

# %%
tau2= 55
ts2= x

perc_FNN, n = FNN_n(ts2, tau2, plotting = True)
print('FNN embedding Dimension: ',n)
# Out:
# FNN embedding Dimension:  3
