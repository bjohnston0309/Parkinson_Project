# %%
import numpy as np 
import math
import matplotlib.pyplot as plt
import pandas as pd 

x = np.linspace(0,26,26)
y = [0,1,2,3,4,5,6,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7]

plt.plot(x,y)
plt.ylim(0,12)
plt.xlim(0,25)
plt.xlabel('$Time$', fontsize=14)
plt.ylabel('$<ln(divergence)>$', fontsize=14)
plt.xticks([])
plt.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)
